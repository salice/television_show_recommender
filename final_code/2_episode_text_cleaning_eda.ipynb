# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob, time, datetime, re

# %%
files = glob.glob("../data/springfield_springfield_all/"+"*.csv")
shows = pd.concat([pd.read_csv(file, lineterminator='\n') for file in files])

# %%
shows.shape
# Out:
# (117937, 3)

# %%
shows.head()
# Out:
#                                                 text  \
# 0  Can it be the breeze that fills the trees\r  W...
# 1  Madame Peyet is in the family way.\r  She is p...
# 2  Ooar!\r  Ooh!\r  Are you by any chance curious...
# 3  It is possible that\r the more curious among y...
# 4  Oh. Do you by any chance wish to know\r  how I...
#
#                   episode_name                                  show_name
# 0        The Nicked Knockwurst  'Allo 'Allo! (1982) s03e01 Episode Script
# 1     Gruber Does Some Mincing  'Allo 'Allo! (1982) s03e02 Episode Script
# 2  The Sausage in the Wardrobe  'Allo 'Allo! (1982) s03e03 Episode Script
# 3          The Flight of Fancy  'Allo 'Allo! (1982) s03e04 Episode Script
# 4    Pretty Maids All in a Row  'Allo 'Allo! (1982) s03e05 Episode Script

# %%
shows.tail()
# Out:
#                                                     text         episode_name  \
# 42093  : Out of the night When the full moon ls brigh...    The Flaming Arrow
# 42094  : Out of the night When the full moon ls brigh...  Zorro Fights a Duel
# 42095  : Out of the night When the full moon ls brigh...    Amnesty for Zorro
# 42096  : Out of the night When the full moon ls brigh...         The Runaways
# 42097  : Out of the night When the full moon ls brigh...         The Iron Box
#
#                                 show_name
# 42093  Zorro (1957) s02e11 Episode Script
# 42094  Zorro (1957) s02e12 Episode Script
# 42095  Zorro (1957) s02e13 Episode Script
# 42096  Zorro (1957) s02e14 Episode Script
# 42097  Zorro (1957) s02e15 Episode Script

# %%
shows.isnull().sum()
# Out:
# text            151
# episode_name      4
# show_name         1
# dtype: int64

# %%
shows[shows["text"].isnull()]["show_name"].value_counts()
# Out:
# The A-Team (1983) Episode Scripts         15
# Shaun the Sheep (2007) Episode Scripts     9
# TV Show Episode Scripts                    3
# COPS (1989) s27e02 Episode Script          1
# COPS (1989) s26e14 Episode Script          1
#                                           ..
# Top Gear (2002) s10e10 Episode Script      1
# COPS (1989) s26e13 Episode Script          1
# COPS (1989) s28e16 Episode Script          1
# COPS (1989) s27e07 Episode Script          1
# COPS (1989) s27e23 Episode Script          1
# Name: show_name, Length: 126, dtype: int64

# %% [markdown]
# #### Cleaning Show Name Column

# %% [markdown]
# There is one row with no information. Will drop then clean remaining items in show_name column

# %%
shows[shows["show_name"].isnull()].shape
shows = shows.drop(shows[shows["show_name"].isnull()].index)

# %%
shows["show_name"] = shows["show_name"].str.replace("Episode Script", "")

# %% [markdown]
# #### There are 151 rows that do not have a script, will drop

# %%
shows = shows.drop(shows[shows["text"].isnull()].index)

# %%
shows.isnull().sum()
# Out:
# text            0
# episode_name    0
# show_name       0
# dtype: int64

# %%
shows.shape
# Out:
# (117416, 3)

# %%
shows.head()
# Out:
#                                                 text  \
# 0  Can it be the breeze that fills the trees\r  W...
# 1  Madame Peyet is in the family way.\r  She is p...
# 2  Ooar!\r  Ooh!\r  Are you by any chance curious...
# 3  It is possible that\r the more curious among y...
# 4  Oh. Do you by any chance wish to know\r  how I...
#
#                   episode_name                    show_name
# 0        The Nicked Knockwurst  'Allo 'Allo! (1982) s03e01
# 1     Gruber Does Some Mincing  'Allo 'Allo! (1982) s03e02
# 2  The Sausage in the Wardrobe  'Allo 'Allo! (1982) s03e03
# 3          The Flight of Fancy  'Allo 'Allo! (1982) s03e04
# 4    Pretty Maids All in a Row  'Allo 'Allo! (1982) s03e05

# %%
shows.tail()
# Out:
#                                                     text         episode_name  \
# 42093  : Out of the night When the full moon ls brigh...    The Flaming Arrow
# 42094  : Out of the night When the full moon ls brigh...  Zorro Fights a Duel
# 42095  : Out of the night When the full moon ls brigh...    Amnesty for Zorro
# 42096  : Out of the night When the full moon ls brigh...         The Runaways
# 42097  : Out of the night When the full moon ls brigh...         The Iron Box
#
#                   show_name
# 42093  Zorro (1957) s02e11
# 42094  Zorro (1957) s02e12
# 42095  Zorro (1957) s02e13
# 42096  Zorro (1957) s02e14
# 42097  Zorro (1957) s02e15

# %%
shows[shows["show_name"].str.contains(r"s\d{2}e\d*")]
# Out:
#                                                     text  \
# 0      Can it be the breeze that fills the trees\r  W...
# 1      Madame Peyet is in the family way.\r  She is p...
# 2      Ooar!\r  Ooh!\r  Are you by any chance curious...
# 3      It is possible that\r the more curious among y...
# 4      Oh. Do you by any chance wish to know\r  how I...
# ...                                                  ...
# 42093  : Out of the night When the full moon ls brigh...
# 42094  : Out of the night When the full moon ls brigh...
# 42095  : Out of the night When the full moon ls brigh...
# 42096  : Out of the night When the full moon ls brigh...
# 42097  : Out of the night When the full moon ls brigh...
#
#                       episode_name                    show_name
# 0            The Nicked Knockwurst  'Allo 'Allo! (1982) s03e01
# 1         Gruber Does Some Mincing  'Allo 'Allo! (1982) s03e02
# 2      The Sausage in the Wardrobe  'Allo 'Allo! (1982) s03e03
# 3              The Flight of Fancy  'Allo 'Allo! (1982) s03e04
# 4        Pretty Maids All in a Row  'Allo 'Allo! (1982) s03e05
# ...                            ...                          ...
# 42093            The Flaming Arrow         Zorro (1957) s02e11
# 42094          Zorro Fights a Duel         Zorro (1957) s02e12
# 42095            Amnesty for Zorro         Zorro (1957) s02e13
# 42096                 The Runaways         Zorro (1957) s02e14
# 42097                 The Iron Box         Zorro (1957) s02e15
#
# [117409 rows x 3 columns]

# %% [markdown]
# #### Cleaning the show_name column
# Loop through each element, if it contains the season episode pattern, split on the s and then the e to extract the season and episode numbers.

# %%
def clean_show_name_col(df):
    season_nums = []
    episode_nums = []
    show_names = []
    years = []
    manual = []

    for show in df["show_name"]:
        if re.search(r"s\d{2}e\d*", show):
            season_split = show.rsplit("s", maxsplit=1)
            #pulling out the season and episode numbers
            season_episode = season_split[1]
            season_episode_split = season_episode.split("e")
            season_num = season_episode_split[0].strip()
            episode_num = season_episode_split[1].strip()
            season_nums.append(season_num)
            episode_nums.append(episode_num)
            manual.append(0)

            #show name and year (if available)
            show_year = season_split[0]
            if re.search(r"\(\d{4}\)", show_year):
                show_year_split = show_year.rsplit("(", maxsplit=1)
                show_name = show_year_split[0].strip()
                show_names.append(show_name)
                year = show_year_split[1].strip().replace(")", "")
                years.append(year)
            else:
                show_names.append(show_year)
                years.append(0)
        else:
            show_names.append(show)
            manual.append(1)
            season_nums.append("missing")
            episode_nums.append("missing")
            years.append(0)
            
            
    df["show_names"] = show_names
    df["season_number"] = season_nums
    df["episode_number"] = episode_nums
    df["show_year"] = years
    df["manual"] = manual

# %%
clean_show_name_col(shows)

# %%
#remove escape characters and punctuation from text
shows["text"] = shows["text"].str.replace(r"\r|\t|\n|\v", "")

# %%
#shows["text"] = shows["text"].str.replace(r"\.|\,|\?|\!|\-|\(|\)", "")

# %%
#shows["text"] = shows["text"].str.replace(r"\[|\]|\~|\*|\:|\;", "")

# %%
shows["text"] = shows["text"].str.replace("\\", "")

# %%
shows["show_names"] = shows["show_names"].str.replace('"', "")

# %%
#reset index
shows = shows.reset_index(drop=True)

# %%
shows.head(20)
# Out:
#                                                  text  \
# 0   Can it be the breeze that fills the trees  Wit...
# 1   Madame Peyet is in the family way.  She is ple...
# 2   Ooar!  Ooh!  Are you by any chance curious to ...
# 3   It is possible that the more curious among you...
# 4   Oh. Do you by any chance wish to know  how I, ...
# 5   Every little breeze seems to whisper Louise  B...
# 6   There cannot be many French café owners in a p...
# 7   You are probably wondering what I am doing in ...
# 8   Ah The more observant among you  may note that...
# 9   Things are looking up.  A slip of the tongue b...
# 10  At 10 o'clock in the morning it is not usual t...
# 11  Once again, my instincts for self-preservation...
# 12  I'd like to marry a girl that's skinny. I thin...
# 13  * All Right! * Hey! * Oh, oh, oh, oh, oh, oh! ...
# 14  Oh, I took way too much hand cream. Here. What...
# 15  * All right! * Hey! * Oh, oh, oh, oh, oh, oh! ...
# 16  * All right! * Hey! * Oh, oh, oh, oh, oh, oh! ...
# 17  * All right! * Hey! * Oh, oh, oh, oh, oh, oh! ...
# 18  When was the last time I got a phone call? Fin...
# 19  * All right! * Hey! * Oh, oh, oh, oh, oh, oh! ...
#
#                        episode_name                    show_name  \
# 0             The Nicked Knockwurst  'Allo 'Allo! (1982) s03e01
# 1          Gruber Does Some Mincing  'Allo 'Allo! (1982) s03e02
# 2       The Sausage in the Wardrobe  'Allo 'Allo! (1982) s03e03
# 3               The Flight of Fancy  'Allo 'Allo! (1982) s03e04
# 4         Pretty Maids All in a Row  'Allo 'Allo! (1982) s03e05
# 5               The Great Un-Escape  'Allo 'Allo! (1982) s03e06
# 6            Hans Goes Over the Top  'Allo 'Allo! (1982) s04e01
# 7                        Camp Dance  'Allo 'Allo! (1982) s04e02
# 8       Good Staff are Hard to Find  'Allo 'Allo! (1982) s04e03
# 9                    The Flying Nun  'Allo 'Allo! (1982) s04e04
# 10      The Sausage in the Trousers  'Allo 'Allo! (1982) s04e05
# 11  The Jet-Propelled Mother-in-Law  'Allo 'Allo! (1982) s04e06
# 12                            Pilot           'Til Death s01e01
# 13                Sex for Furniture           'Til Death s01e02
# 14                         The Ring           'Til Death s01e03
# 15                    The Wood Pile           'Til Death s01e04
# 16                  The Garage Band           'Til Death s01e05
# 17         Your Mother or Your Wife           'Til Death s01e06
# 18                    Dream Getaway           'Til Death s01e07
# 19                        Death Sex           'Til Death s01e08
#
#       show_names season_number episode_number show_year  manual
# 0   'Allo 'Allo!            03             01      1982       0
# 1   'Allo 'Allo!            03             02      1982       0
# 2   'Allo 'Allo!            03             03      1982       0
# 3   'Allo 'Allo!            03             04      1982       0
# 4   'Allo 'Allo!            03             05      1982       0
# 5   'Allo 'Allo!            03             06      1982       0
# 6   'Allo 'Allo!            04             01      1982       0
# 7   'Allo 'Allo!            04             02      1982       0
# 8   'Allo 'Allo!            04             03      1982       0
# 9   'Allo 'Allo!            04             04      1982       0
# 10  'Allo 'Allo!            04             05      1982       0
# 11  'Allo 'Allo!            04             06      1982       0
# 12   'Til Death             01             01         0       0
# 13   'Til Death             01             02         0       0
# 14   'Til Death             01             03         0       0
# 15   'Til Death             01             04         0       0
# 16   'Til Death             01             05         0       0
# 17   'Til Death             01             06         0       0
# 18   'Til Death             01             07         0       0
# 19   'Til Death             01             08         0       0

# %%
something = shows.loc[0, "text"]

# %%
something.replace('\\', '')

# %%
something[:800]

# %%
shows["show_year"].value_counts()

# %%
shows["manual"].value_counts()

# %%
shows["show_year"] = shows["show_year"].astype(int)

# %%
shows[shows["manual"] == 1]
# Out:
#                                                     text  \
# 1593   This programme contains strong language and ad...
# 7689   JTBC Idol Room Episode 26 - Twice   [Ye~ Come ...
# 47298  Martin. Louisa. Come on through.  Hello, Dr Ry...
# 54360  1 Previously on AMC's "Fear the Walking Dead" ...
# 55332  - (CHATTERING) - (LIVELY MUSIC)  The Toronto S...
# 89211  1 I'm having this baby here!  Cheyenne, this i...
# 94957  We've seen fragments before,  enough to confir...
#
#                                             episode_name  \
# 1593   Alan Carr, Kevin Bridges, Cariad Lloyd, Elis J...
# 7689                                               Twice
# 47298                                        Equilibrium
# 54360                         Another Day in the Diamond
# 55332                                      Extra Innings
# 89211                                             Strike
# 94957                                The Hell Within Him
#
#                                             show_name  \
# 1593   8 Out Of 10 Cats Does Countdown (2012) a12e01
# 7689                         Idol Room (2018) s-1e26
# 47298                       Doc Martin (2004) s0e906
# 54360            Fear The Walking Dead (2015) s040e2
# 55332          Frankie Drake Mysteries (2017) s020e6
# 89211                       Superstore (2015) s020e1
# 94957                         The Fall (2013) s0e304
#
#                                            show_names season_number  \
# 1593   8 Out Of 10 Cats Does Countdown (2012) a12e01        missing
# 7689                         Idol Room (2018) s-1e26        missing
# 47298                       Doc Martin (2004) s0e906        missing
# 54360            Fear The Walking Dead (2015) s040e2        missing
# 55332          Frankie Drake Mysteries (2017) s020e6        missing
# 89211                       Superstore (2015) s020e1        missing
# 94957                         The Fall (2013) s0e304        missing
#
#       episode_number  show_year  manual
# 1593         missing          0       1
# 7689         missing          0       1
# 47298        missing          0       1
# 54360        missing          0       1
# 55332        missing          0       1
# 89211        missing          0       1
# 94957        missing          0       1

# %%
#manual cleaning of 7 rows with typos and not caught by function
shows.at[1593, "season_number"] = 12
shows.at[1593, "episode_number"] = 1
shows.at[1593, "show_names"] = "8 Out of 10 Cats Does Countdown"
shows.at[1593, "show_year"] = 2012

shows.at[7689, "show_names"] = "Idol Room"
shows.at[7689, "season_number"] = 1
shows.at[7689, "episode_number"] = 26
shows.at[7689, "show_year"] = 2018

shows.at[47298, "show_names"] = "Doc Martin"
shows.at[47298, "season_number"] = 9
shows.at[47298, "episode_number"] = 6
shows.at[47298, "show_year"] = 2004

shows.at[54360, "show_names"] = "Fear the Walking Dead"
shows.at[54360, "season_number"] = 4
shows.at[54360, "episode_number"] = 2
shows.at[54360, "show_year"] = 2015

shows.at[55332, "show_names"] = "Frankie Drake Mysteries"
shows.at[55332, "season_number"] = 2
shows.at[55332, "episode_number"] = 6
shows.at[55332, "show_year"] = 2017

shows.at[89211, "show_names"] = "Superstore"
shows.at[89211, "season_number"] = 2
shows.at[89211, "episode_number"] = 1
shows.at[89211, "show_year"] = 2015

shows.at[94957, "show_names"] = "The Fall"
shows.at[94957, "season_number"] = 3
shows.at[94957, "episode_number"] = 4
shows.at[94957, "show_year"] = 2013

# %%
#check rows
shows.loc[[1593, 7689, 47298, 54360, 55332, 89211, 94957]]
# Out:
#                                                     text  \
# 1593   This programme contains strong language and ad...
# 7689   JTBC Idol Room Episode 26 - Twice   [Ye~ Come ...
# 47298  Martin. Louisa. Come on through.  Hello, Dr Ry...
# 54360  1 Previously on AMC's "Fear the Walking Dead" ...
# 55332  - (CHATTERING) - (LIVELY MUSIC)  The Toronto S...
# 89211  1 I'm having this baby here!  Cheyenne, this i...
# 94957  We've seen fragments before,  enough to confir...
#
#                                             episode_name  \
# 1593   Alan Carr, Kevin Bridges, Cariad Lloyd, Elis J...
# 7689                                               Twice
# 47298                                        Equilibrium
# 54360                         Another Day in the Diamond
# 55332                                      Extra Innings
# 89211                                             Strike
# 94957                                The Hell Within Him
#
#                                             show_name  \
# 1593   8 Out Of 10 Cats Does Countdown (2012) a12e01
# 7689                         Idol Room (2018) s-1e26
# 47298                       Doc Martin (2004) s0e906
# 54360            Fear The Walking Dead (2015) s040e2
# 55332          Frankie Drake Mysteries (2017) s020e6
# 89211                       Superstore (2015) s020e1
# 94957                         The Fall (2013) s0e304
#
#                             show_names season_number episode_number  \
# 1593   8 Out of 10 Cats Does Countdown            12              1
# 7689                         Idol Room             1             26
# 47298                       Doc Martin             9              6
# 54360            Fear the Walking Dead             4              2
# 55332          Frankie Drake Mysteries             2              6
# 89211                       Superstore             2              1
# 94957                         The Fall             3              4
#
#        show_year  manual
# 1593        2012       1
# 7689        2018       1
# 47298       2004       1
# 54360       2015       1
# 55332       2017       1
# 89211       2015       1
# 94957       2013       1

# %%
#drop show_name column and manual now that show_name column is cleaned
shows = shows.drop(columns=["show_name", "manual"])

# %%
shows.head()
# Out:
#                                                 text  \
# 0  Can it be the breeze that fills the trees  Wit...
# 1  Madame Peyet is in the family way.  She is ple...
# 2  Ooar!  Ooh!  Are you by any chance curious to ...
# 3  It is possible that the more curious among you...
# 4  Oh. Do you by any chance wish to know  how I, ...
#
#                   episode_name    show_names season_number episode_number  \
# 0        The Nicked Knockwurst  'Allo 'Allo!            03             01
# 1     Gruber Does Some Mincing  'Allo 'Allo!            03             02
# 2  The Sausage in the Wardrobe  'Allo 'Allo!            03             03
# 3          The Flight of Fancy  'Allo 'Allo!            03             04
# 4    Pretty Maids All in a Row  'Allo 'Allo!            03             05
#
#    show_year
# 0       1982
# 1       1982
# 2       1982
# 3       1982
# 4       1982

# %%
#just in case remove any whitespaces from show_names
shows["show_names"] = [show.strip() for show in shows["show_names"]]

# %%
#create csv with cleaned episodes
shows.to_csv("../data/episodes_cleaned.csv", index=False)

# %% [markdown]
# #### 4667 TV shows total

# %%
len(set(shows["show_names"]))
# Out:
# 4667

# %% [markdown]
# ##### creating a list of all the show names in dataset to use to grab user reviews from another site

# %%
show_list = list(set(shows["show_names"]))

# %%
show_list
# Out:
# ['Plebs',
#  'The Murders',
#  'Mork and Mindy',
#  'Republic of Doyle',
#  'The Playboy Club',
#  'The Mystery of Edwin Drood',
#  'Material Girl',
#  'Persona 4: The Animation',
#  'The Amazing Race',
#  'Doctor Who Extra',
#  'Father Brown',
#  'Britain by Bike',
#  'Mind Games',
#  'Victim Number 8',
#  'Sneaky Pete',
#  'Sanford and Son',
#  'Suspects',
#  'Costume Quest',
#  'Profiler',
#  'Baretta',
#  "Lil' Bush: Resident of the United States",
#  'The Edwardians',
#  'Aqua Teen Hunger Force',
#  'Studio One',
#  'Kavanagh QC',
#  'The Magicians',
#  'Tru Calling',
#  'HarmonQuest',
#  'Jake 2.0',
#  'The Carrie Diaries',
#  'The Get Down',
#  'Eastwick',
#  'The Muppets',
#  'The Company',
#  'Millennium',
#  'Kung Fu',
#  'Strangers',
#  'Gormenghast',
#  'Big Day',
#  'Jean Claude Van Johnson',
#  'Whose Line Is It Anyway?',
#  'Sick Note',
#  'Natural World',
#  'Bloody Tales of the Tower',
#  'Skins',
#  'Endgame',
#  'Drop Dead Diva',
#  'After the Runway',
#  'Cranford',
#  "That's So Raven",
#  'Getting On',
#  'Empires: The Roman Empire in the First Century',
#  'Shooting the War',
#  'Spooks: Code 9',
#  'The Orville',
#  'Bizaardvark',
#  'TripTank',
#  'The League',
#  'VICE Does America',
#  'Matroesjkas',
#  'Are You Being Served?',
#  'Jing: King of Bandits',
#  'Masters of Money',
#  'Frontline Medicine',
#  'Nip/Tuck',
#  'Armada: 12 Days to Save England',
#  'Scrapheap Challenge',
#  'The Adventures of Kid Danger',
#  'Perils of Penelope Pitstop',
#  'The White Princess',
#  'Elfen Lied',
#  'Working The Engels',
#  'City Hunter (Siti hyunteo)',
#  'Disenchantment',
#  'Frasier',
#  'Slutever',
#  'Divine: The Series',
#  'Frontera Verde',
#  'Doom Patrol',
#  'Graceland',
#  'Reggie Perrin',
#  'Spun Out',
#  'Nightcap',
#  'Top Coppers',
#  'Thirteen',
#  "Angela's Eyes",
#  'How Do You Want Me?',
#  "That '70s Show",
#  'Mr Pickles',
#  'Teachers',
#  'Disasters at Sea',
#  'The Jury',
#  'Top Gear (US)',
#  'Dice',
#  'Great Night Out',
#  'In With The Flynns',
#  'Queen of the World',
#  'Love, Lies & Records',
#  'Son of Zorn',
#  'The Fades',
#  "Ken Follett's Journey Into the Dark Ages",
#  'Extinct',
#  'Doctor Who',
#  'Cancer: The Emperor of All Maladies',
#  'Capadocia',
#  'Collision',
#  'David Beckham: Into the Unknown',
#  'The Guardian',
#  'The Last Leg Goes Down',
#  'Tina and Bobby',
#  'Corner Gas Animated',
#  'The Apprentice (UK)',
#  'Keeping Faith',
#  'One Night',
#  'Sound Of Song',
#  'Fuller House',
#  'The Disappearance of Natalee Holloway',
#  'The Paradise',
#  "Three's Company",
#  'Will and Grace',
#  'Fallen',
#  "Callan's Kicks",
#  'The British',
#  'Perpetual Grace, LTD',
#  'The Good Cop',
#  'Ghostfacers',
#  'Spooksville',
#  'Tripping the Rift',
#  "Andrew Marr's History Of The World",
#  'Wild Arabia',
#  'Doomsday Preppers',
#  'The Ben Stiller Show',
#  'Frontier',
#  'Off The Map',
#  'Armchair Voyage: Hellenic Cruise',
#  'ReBoot: The Guardian Code',
#  'Seitokai yakuindomo',
#  'Siempre Bruja',
#  'Bodyguard',
#  'The Night Shift',
#  'Digimon Adventure',
#  'Titanic: Blood and Steel',
#  'Cold Feet',
#  'Cold Case',
#  "Rick Stein's India",
#  'Delete',
#  'SuperMansion',
#  'The Classic Car Show',
#  'White Van Man',
#  'Frankie Drake Mysteries',
#  'Ice Cream Girls',
#  'Only Fools and Horses',
#  'Lady Dynamite',
#  'Age Before Beauty',
#  'Northern Rescue',
#  'Beavis and Butt-Head',
#  'Altered Carbon',
#  'Legend of the Seeker',
#  'Damien',
#  'How Earth Made Us',
#  'Web Therapy',
#  'Tremors',
#  'QI',
#  'Seinto Seiya: The Lost Canvas - Meiou Shinwa',
#  'The Newsroom',
#  'The Lizzie Borden Chronicles',
#  'Secrets and Lies',
#  'Zero Hour',
#  'A Moody Christmas',
#  'Mrs Biggs',
#  'Big Hero 6: The Series',
#  'Haikyuu!!',
#  'Outnumbered',
#  'The Twilight Zone',
#  'American Horror Story',
#  'No Game, No Life',
#  'Paradise PD',
#  'Love/Hate',
#  'Wasted',
#  'Star Trek: The Next Generation',
#  'How the Universe Works',
#  'Friday On My Mind',
#  'The Colony',
#  'Upstart Crow',
#  'Murder Mountain',
#  "Stewart Lee's Comedy Vehicle",
#  'Heroes Reborn',
#  'Medieval Lives',
#  'Gigi Does It',
#  'Zhen Huan Zhuan',
#  'Jonah From Tonga',
#  'Pretty Little Liars: The Perfectionists',
#  'Chaos',
#  'Boss',
#  'A Series Of Unfortunate Events',
#  'War and Remembrance',
#  'The Worst Week of My Life',
#  'The Dresden Files',
#  'Rosehaven',
#  'The Great British Bake Off - An Extra Slice',
#  'Edha',
#  'Starlings',
#  'Shut Eye',
#  'The Secret Life of Marilyn Monroe',
#  'The American West',
#  'Inside Amy Schumer',
#  "Fry's Planet Word",
#  'Godfather of Harlem',
#  'Leaving',
#  'Tin Star',
#  'Shooting Stars',
#  'Mimi',
#  'Steak Out with Kix Brooks',
#  'Secret Girlfriend',
#  'SEAL Team',
#  'Tell Me a Story (US)',
#  'Cape Wrath',
#  'We The Jury',
#  '1066 The Battle For Middle Earth',
#  'Tin Man',
#  'El Chapo',
#  'Flight of the Conchords',
#  'Wonders of Life',
#  'Dads',
#  'Casanova (BBC)',
#  'Ghosts',
#  'Mankind: The Story of All of Us',
#  'Operation Stonehenge',
#  'Hell on Wheels',
#  'John Doe',
#  'Rake',
#  'Haunted Live',
#  'Top Chef: Masters',
#  "Mary Berry's Country House Secrets",
#  'Winx Club',
#  'Gigolos',
#  'All American',
#  'Are You Afraid of the Dark',
#  'Tengen Toppa Gurren Lagann',
#  'The Confession',
#  'Fargo',
#  'Last of the Summer Wine',
#  'Downton Abbey',
#  'The Kettering Incident',
#  '13 Steps Down',
#  'Monkey Dust',
#  'Money Heist',
#  'Brave New World with Stephen Hawking',
#  'Death Valley',
#  'Doogie Howser, M.D.',
#  'Signed, Sealed, Delivered',
#  'Mother Up',
#  'Suburra',
#  'The Burrowers',
#  'Inside The Human Body',
#  'Golan the Insatiable',
#  'Speed Kills',
#  'TURN',
#  'Worst Year of My Life, Again!',
#  'The Ghost Squad',
#  '07 Ghost',
#  'Earthflight',
#  'The Greeks',
#  'Barracuda',
#  'The Blacklist',
#  'God Friended Me',
#  'Jeremiah',
#  'In the Long Run',
#  'Love Child',
#  'The Smoke',
#  'Brassic',
#  'Come Fly With Me',
#  '55 Degrees North',
#  'Battlestar Galactica: The Face of the Enemy',
#  'Growing Up Poor',
#  "Brad Neely's Harg Nallin' Sclopio Peepio",
#  'He Kills Coppers',
#  'Testees',
#  'Van Helsing',
#  'Keeping Up With The Kardashians',
#  '10 Things I Hate About You',
#  'Fear the Walking Dead: Flight 462',
#  'Other Space',
#  'Star Wars, Droid Tales',
#  'Trollhunters',
#  'Bubuki Buranki',
#  'La catedral del mar',
#  'Duck Dodgers',
#  'Gamma',
#  'The Detour',
#  'Queen America',
#  'Blunt Talk',
#  'Animorphs',
#  'Delhi Crime',
#  'Star Wars: Forces of Destiny',
#  'Gomorra',
#  'Meet The Romans',
#  'Empire',
#  'This Way Up',
#  'Space: 1999',
#  'Younger',
#  "Bobcat Goldthwait's Misfits & Monsters",
#  'Modus',
#  'Galapagos with David Attenborough',
#  'Alphas',
#  'Bellevue',
#  'Ordinary Lies',
#  'The Polar Bear Family and Me',
#  '8 Out Of 10 Cats Does Countdown',
#  'A.D. The Bible Continues',
#  'The Long Firm',
#  'Southland',
#  'Out With Dad',
#  'Carrier',
#  'Justified',
#  'Cars Toon',
#  'Penny Dreadful',
#  'Moonbeam City',
#  'Treasures of Ancient Egypt',
#  'Making History',
#  'Max Steel',
#  'Family Matters',
#  'Tiempos de guerra',
#  'Bugsplat!',
#  'Cedar Cove',
#  'Mary Bryant',
#  'Gossip Girl',
#  'Queen Sugar',
#  '666 Park Avenue',
#  'Mid Morning Matters with Alan Partridge',
#  'The Americans',
#  'The Mantis',
#  'A History of Scotland',
#  'Eddie Izzard: Marathon Man',
#  'Broadchurch',
#  'Carnival Row',
#  'Great Teacher Onizuka (GTO)',
#  'The Comedy Get Down',
#  'Harsh Realm',
#  'Outlaw',
#  'Dirty Jobs',
#  'Girls',
#  'I Am Cait',
#  'Sahsiyet',
#  'Bad Girls',
#  'Camelot',
#  'Shoot the Messenger',
#  'Being Human (US)',
#  'Enlightened',
#  'Limitless',
#  'Blitz Street',
#  'Pioneer One',
#  'Surviving R Kelly',
#  'Shock and Awe: The Story of Electricity',
#  'Harold and the Purple Crayon',
#  'Rekyl',
#  'Maelstrom',
#  "Gordon's Great Escape",
#  'Super Fun Night',
#  'Olivia Newton-John: Hopelessly Devoted to You 2018)',
#  'Houdini',
#  'The Millers',
#  'Gold Rush',
#  'Married with Children',
#  'Animal Planet Wild Russia',
#  'Taboo',
#  'Defying Gravity',
#  'Privates',
#  '101 Ways to Leave a Game Show',
#  'Rubicon',
#  'MotherFatherSon',
#  'City on a Hill',
#  'Dominion',
#  'Tron: Uprising',
#  'The Planets',
#  'CSI: Crime Scene Investigation',
#  'The Last Panthers',
#  'Little Boy Blue',
#  'The Unit',
#  "Joanna Lumley's Postcards From My Travels",
#  'Rome Unpacked',
#  "Marvel's Avengers Assemble",
#  'Meet the Ancestors',
#  'Brooklyn Nine-Nine',
#  'Danger 5',
#  'Matador (US)',
#  "Marvel's Guardians Of The Galaxy",
#  'Girlfriends',
#  'Make Me a Supermodel',
#  'Crusade',
#  'Heading Out',
#  'State of Play',
#  'Four Kings',
#  'Heavy',
#  'Scream',
#  'The Batman',
#  'Traveler',
#  'White Famous',
#  'Vida',
#  'The Coroner',
#  'Clean Break',
#  'Fog and Crimes',
#  'W1A',
#  'The Meltdown with Jonah and Kumail',
#  'Eleventh Hour',
#  'Royal Pains',
#  'The Inbetweeners',
#  '13 Reasons Why',
#  'Grandfathered',
#  'Vexed',
#  'Mad',
#  'Molly',
#  'Baccano!',
#  'Narcos: Mexico',
#  'Open All Hours',
#  "Russell Howard's Good News",
#  'The Awesomes',
#  'The Long Song',
#  'Knights of Sidonia (Sidonia no Kishi)',
#  'Alice',
#  'The Chi',
#  'Rich Man, Poor Man',
#  "World's Toughest Driving Tests",
#  'Extreme Universe',
#  'Squidbillies',
#  "Japan: Earth's Enchanted Islands",
#  'Brothers',
#  'Spartacus: Blood and Sand',
#  'Jane by Design',
#  'What About Brian',
#  'Single Parents',
#  'Star Trek',
#  'The Unusuals',
#  'Life On Mars (US)',
#  '45 Revoluciones',
#  'Heartless',
#  'Players',
#  'The Righteous Gemstones',
#  'When Heroes Fly',
#  'Wolfblood',
#  'Crashing (US)',
#  'Brigada Costa del Sol',
#  'Kevin (Probably) Saves the World',
#  'Castle Rock',
#  'Emerald City',
#  'Eureka',
#  'Teen Titans Go!',
#  'Taggart',
#  'NOVA scienceNOW',
#  'The Truth About...',
#  'Pulling',
#  'Castlevania',
#  'South Riding',
#  'No Activity',
#  'Hilda',
#  'Master of None',
#  'Fleming: The Man Who Would Be Bond',
#  'The Enfield Haunting',
#  'Malibu Rescue',
#  'Thief',
#  'House, M.D.',
#  'Warehouse 13',
#  'Life',
#  'Blue Mountain State',
#  'Bored to Death',
#  'Kidnapped',
#  'Mapp and Lucia',
#  '15 Storeys High',
#  'Another Period',
#  'Coming of Age',
#  'Escape at Dannemora',
#  'The Magnavox Theatre',
#  'Skam',
#  'Sunshine',
#  'Tracey Breaks the News',
#  'The Saboteurs (aka The Heavy Water War)',
#  'Hello Ladies',
#  'Fair Isle - Living On the Edge',
#  'Bionic Woman',
#  'Scooby-Doo And Guess Who?',
#  'Package Deal',
#  'Mercy',
#  'Bullet in the Face',
#  'All Rise',
#  'When We Rise',
#  'Animaniacs',
#  'The Killer Speaks',
#  'The Good Wife',
#  'The Suite Life of Zack & Cody',
#  'Outsiders',
#  'The Jim Gaffigan Show',
#  "Footballers' Wives",
#  'Metal Hurlant Chronicles',
#  'Most Beautiful Thing',
#  'Play It Again, Dick',
#  'Remedy',
#  'Rock and Chips',
#  'Taken',
#  'Corporate',
#  'Fact or Faked: Paranormal Files',
#  'Condor',
#  'Primeval: New World',
#  'All Star Revue',
#  'Secret City',
#  'Bikie Wars: Brothers in Arms',
#  'Guardians of the Galaxy: Origins',
#  'Lone Star',
#  'The Frankenstein Chronicles',
#  'Born to be Wild: The Golden Age of American Rock',
#  'Rake US',
#  'Thundercats',
#  'Injustice',
#  'Australia With Simon Reeve',
#  "BBC Churchill's Bodyguard",
#  'Whitney Cummings: I Love You',
#  "Marvel's The Defenders",
#  'Trailer Park Boys: The Animated Series',
#  'Celebrity Island with Bear Grylls',
#  'Beecham House',
#  "Gamer's Guide To Pretty Much Everything",
#  'Dark Mon£y',
#  'The Delivery Man',
#  'You Are Wanted',
#  'Demons',
#  'Rab C. Nesbitt',
#  'Kamen no Maid Guy',
#  'Origin',
#  'Scooby-Doo Mystery Incorporated',
#  'Strike Back',
#  'Work It',
#  'Walking Through History',
#  'Gangland Undercover',
#  'The White Queen',
#  'NYC 22',
#  'Exile',
#  'American Playboy: The Hugh Hefner Story',
#  'Durham County',
#  'Backstrom',
#  'Deadbeat',
#  'Neon Genesis Evangelion',
#  'Chimerica',
#  'Satisfaction',
#  'The Other Two',
#  'Unsafe Sex in the City',
#  'Hope Springs',
#  'Monsters vs. Aliens',
#  'Body of Proof',
#  'Boy Meets World',
#  "Schitt's Creek",
#  'Swamp Loggers',
#  'The State Within',
#  'Wu-Tang: An American Saga',
#  'Jamestown',
#  'Jamaica Inn',
#  'The Roosevelts: An Intimate History',
#  'The Firm',
#  'Battlestar Galactica: Blood & Chrome',
#  'Casual',
#  'Miranda',
#  'The Avengers',
#  'The Thick of It',
#  'Upstairs, Downstairs',
#  'Army Wives',
#  'Revenge',
#  'Enlisted',
#  'Dates',
#  'Napoleon',
#  'Roswell, New Mexico',
#  'True Detective',
#  'Maniac',
#  'Breakout Kings',
#  'Trolls: The Beat Goes On!',
#  'The Legend of Master Legend',
#  'Frisky Dingo',
#  'Cake',
#  'O Escolhido',
#  'Run with the Wind',
#  'Sweet/Vicious',
#  'The Hollow',
#  'Step Up: High Water',
#  'The Capture',
#  'Glory Daze',
#  'The Fast Show',
#  'The Kennedys (UK)',
#  'Whites',
#  'Power Rangers',
#  'Young Drunk Punk',
#  'His Dark Materials',
#  'Mad Love',
#  'House Husbands',
#  'Badults',
#  'Mayans M.C.',
#  'For All Mankind',
#  'Penguin Island',
#  'King',
#  'Spaced',
#  'Fosse/Verdon',
#  'Comedy Playhouse',
#  'Freakazoid!',
#  'Planet Earth Live',
#  'Rhoda',
#  'Dark Matter',
#  'And Then There Were None',
#  'The Men Who Built America',
#  'The Order',
#  'Inspector George Gently',
#  'Haunted Towns',
#  'The Kids Are Alright',
#  'Mr. Mom',
#  'Deception',
#  'Light as a Feather',
#  'Comedy Showcase',
#  'Criminal Justice',
#  'Hart of Dixie',
#  'The Profit',
#  'The Office (US)',
#  'T.J. Hooker',
#  'Four Star Playhouse',
#  'The Brokenwood Mysteries',
#  'Thirtysomething',
#  'Happy Town',
#  'Loaded',
#  "Richard Hammond's Miracles of Nature",
#  'Scenes from a Marriage',
#  'Creeped Out',
#  'Lip Sync Battle',
#  'Have I Got a Bit More News for You',
#  'Fresh Off The Boat',
#  'Sir Mortimer and Magnus',
#  'The Onion News Network',
#  'The Ex-PM',
#  'CHiPs',
#  'The Grinder',
#  'Unsolved: The Murders of Tupac and the Notorious B.I.G.',
#  'Walking and Talking',
#  'Lego Star Wars: The Resistance Rises',
#  'Operation Good Guys',
#  'Grown-ish',
#  'Alias J.J.',
#  'Terriers',
#  'Tipping the Velvet',
#  'Heartland (CA)',
#  'The Outcast',
#  'Place of Execution',
#  'The Frost Report',
#  'BBC D-Day to Berlin',
#  'The Storyteller: Greek Myths',
#  'The Ex List',
#  'Comedy Bang! Bang!',
#  'Freakshow',
#  'The Impressions Show with Culshaw and Stephenson',
#  "L.A.'s Finest",
#  'In the Dark',
#  'L5',
#  'Forever',
#  'A Confession',
#  'GLOW',
#  'Two Greedy Italians',
#  "Scooby's All Star Laff A Lympics",
#  'Rescue Me',
#  'The Secret Life of the American Teenager',
#  'Up Pompeii',
#  'Hotter Than My Daughter',
#  'Looking for Alaska',
#  'Midnight, Texas',
#  'Combat!',
#  'Doubt',
#  'Tatau',
#  'Face-Maker',
#  'A Bit of Fry & Laurie',
#  'Charlie Jade',
#  'Crunch Time',
#  'Fantastic Four',
#  'Birds of Prey',
#  'The Bleak Old Shop of Stuff',
#  'Hot Date',
#  'Law & Order: Los Angeles',
#  'Monday Mornings',
#  'The Cosmopolitans',
#  'Lovesick (Scrotal Recall)',
#  'Mystery Girls',
#  'Reverie',
#  'Action Team',
#  'Crime Squad',
#  'Dystopia',
#  'Ben and Kate',
#  'Who Gets the Last Laugh?',
#  'Here and Now',
#  'Cane',
#  'This is Jinsy',
#  'Andromeda',
#  'Aftermath',
#  'Vinyl',
#  'Just Good Friends',
#  'People Like Us',
#  'Damned',
#  'Romantically Challenged',
#  'Zac and Mia',
#  'Ultraviolet',
#  'The Munsters',
#  'Really',
#  'The Wild Wild West',
#  "Wallace and Gromit's World of Invention",
#  'City of Vice',
#  'The Ren and Stimpy Show',
#  '1864',
#  'Modern Love',
#  'Private Eyes',
#  'DCI Banks Aftermath',
#  'The Project (US)',
#  'Touch',
#  'Siblings',
#  'Harlots',
#  "A Young Doctor's Notebook",
#  'The Flash',
#  '1992',
#  'Hunted',
#  'Love Rain (Sarangbi)',
#  'The Casual Vacancy',
#  'Stag',
#  'Stitchers',
#  'Victoria',
#  'Chernobyl',
#  'American Dad',
#  'Backstage',
#  'The Real Hustle',
#  'Boomers',
#  'Would I Lie To You?',
#  'Brotherhood',
#  'Homeland',
#  'Apocalypse - The Second World War',
#  'The Deep End',
#  'Zorro',
#  'Whiskey Cavalier',
#  'The Mindy Project',
#  'Knight Squad',
#  'Seven Seconds',
#  'Pinky and the Brain',
#  'Stephen Fry: Out There',
#  'Moone Boy',
#  'Damo',
#  'Mind Field',
#  'Get Shorty',
#  'That Winter, The Wind Blows',
#  'Puppy Love',
#  'Sensitive Skin',
#  'Manhunt',
#  'Small Time Gangster',
#  'SunTrap',
#  'Z Rock',
#  'Climax!',
#  'You Me Her',
#  'Ugly Americans',
#  'The Adventures of Tintin',
#  'V: The Final Battle',
#  'Orangutan Diary',
#  'The Brink',
#  'Destination Truth',
#  'A Passionate Woman',
#  'Haters Back Off',
#  'Ghost Hunters',
#  'Timeless',
#  "Foyle's War",
#  'Shameless',
#  'Planet Earth II',
#  'Detective Conan',
#  'The Player',
#  'Mad About You',
#  'Jessie',
#  'No Man Left Behind',
#  'Clash of the Gods',
#  'Played',
#  'Terminator Salvation: The Machinima Series',
#  'The Dead Zone',
#  'Durarara!!',
#  'Newzoids',
#  'BBC Yellowstone',
#  "David Starkey's Music and Monarchy",
#  'How the World Ends',
#  'Camping (US)',
#  'Black Widows',
#  'Pride and Prejudice',
#  'Madiba',
#  'Good Girls Revolt',
#  'The Goode Family',
#  'Significant Mother',
#  'Quantum Leap',
#  'Boardwalk Empire',
#  'Hanna',
#  'Axe Cop',
#  'Human Planet',
#  'Cyberwar',
#  'Beware The Batman',
#  'No Good Nick',
#  '18 to Life',
#  'Queer Britain',
#  "Hogan's Heroes",
#  'All About The Washingtons',
#  'Creepshow',
#  "Kim's Convenience",
#  'A Haunting',
#  'Celebrity Squares',
#  'Forever Knight',
#  'No Tomorrow',
#  'The Walking Dead',
#  'Glitch',
#  'Camp',
#  'Playing with Fire',
#  'Parasyte: The Maxim',
#  'Midsomer Murders',
#  'The Thorn Birds',
#  'Love Bites',
#  'Return of the Mac',
#  'Jann',
#  'Mech-X4',
#  'Hap and Leonard',
#  'Gunsmoke',
#  'Neverwhere',
#  'Rosario + Vampire',
#  'All Night',
#  'Labyrinth',
#  'Agents of S.H.I.E.L.D.',
#  'Highlander: The Raven',
#  'Banished',
#  'The Putin Interviews',
#  'Banshee Origins',
#  'Scarborough',
#  'The Secret Agent',
#  'The Tom and Jerry Show',
#  'Robotech',
#  'Cornwall, with Caroline Quentin',
#  'Threshold',
#  "The Hairy Bikers' Northern Exposure",
#  'Oceans',
#  'Breakthrough',
#  "Chef's Table",
#  "Betty White's Off Their Rockers",
#  'Future Sex',
#  'Torchwood',
#  'A Stitch in Time',
#  'Somewhere Between',
#  'Anger Management',
#  "The Elegant Gentleman's Guide To Knife Fighting",
#  "Uranium: Twisting the Dragon's Tail",
#  'Father Figure',
#  'Without You',
#  'Class',
#  'Emma',
#  'Drake and Josh',
#  'Ashes To Ashes',
#  'Lost Land of the Tiger',
#  'Lunch Monkeys',
#  'Weird Science',
#  'Great News',
#  'Ozark',
#  'Valley of the Boom',
#  "Robert Kirkman's Secret History of Comics",
#  'Bones',
#  "Don't Trust the B---- in Apartment 23",
#  'Las Vegas',
#  'Being Human (UK)',
#  'Hidden/Craith',
#  'The Outpost',
#  "The Girl's Guide to Depravity",
#  'Charmed',
#  'Fungus the Bogeyman',
#  'The Young Ones',
#  'Wallander',
#  'Meadowlands',
#  "Smiley's People",
#  'Lie To Me',
#  'Tower Prep',
#  'Breaking In',
#  'A Very British Murder with Lucy Worsley',
#  'Secret Britain',
#  'The Straits',
#  'Wikileaks: The Secret Life of a Superpower',
#  'Kings',
#  'Banana',
#  'Chesapeake Shores',
#  'FM',
#  'Norsemen',
#  'Galavant',
#  'Cockroaches',
#  'Shooting the Past',
#  'Paula',
#  'Kodenavn Hunter',
#  'First Civilizations',
#  'Ghost Adventures Aftershocks',
#  '4 Blocks',
#  'Heroes Reborn: Dark Matters',
#  "RuPaul's Drag Race",
#  'The Hour',
#  'The Secret Circle',
#  'Cold Blood',
#  'Killjoys',
#  'Hunter x Hunter',
#  'Luna Petunia: Return to Amazia',
#  'The Chinaboy Show',
#  'Now Apocalypse',
#  'Billy and Billie',
#  'Greek',
#  'The Gates',
#  'High Moon',
#  'The Riches',
#  'Black Monday',
#  'Science And Islam',
#  'Josh',
#  '21 Thunder',
#  'NTSF:SD:SUV::',
#  'Charlotte',
#  'On the Couch',
#  '9JKL',
#  'Gintama',
#  'SS-GB',
#  'Shake It Up!',
#  'Bron',
#  'Lambs of God',
#  'A History of Ancient Britain (BBC)',
#  'House of Lies',
#  'Easy',
#  'Green Eggs and Ham',
#  'Richard Hammond Builds a Planet',
#  'The Art Of More',
#  'What Would Sal Do',
#  "Richard Hammond's Jungle Quest",
#  'The Blacklist: Redemption',
#  'The Job Lot',
#  "Noah's Arc",
#  'CatDog',
#  'Troy: Fall of a City',
#  'Micro Monsters with David Attenborough',
#  'M.I. High',
#  'Louie',
#  'Cyborg 009: Call of Justice',
#  'The Hollow Crown',
#  'The Naked Chef',
#  'Broad City',
#  'The Unicorn',
#  'Uncle Buck',
#  'Two Doors Down',
#  'Scariest Night of My Life',
#  'The Tudors',
#  'Mr Inbetween',
#  'Zomboat!',
#  "Stephen Hawking's Grand Design",
#  'Still Star-Crossed',
#  'Edge',
#  'Dragons: Riders of Berk',
#  'Evil',
#  'Reef Break',
#  "Marvel's Luke Cage",
#  'Marseille',
#  'The Story of Musicals',
#  "'Til Death",
#  'Weird Loners',
#  'ID-0',
#  'Bates Motel',
#  'Man with a Plan',
#  'The State',
#  'Filthy Rich and Catflap',
#  'Black Sheep Squadron',
#  'Expedition Impossible',
#  'Airwolf',
#  'The Code AU',
#  'Lip Sync Battle UK',
#  'The Name of the Rose',
#  'White Collar',
#  "'Allo 'Allo!",
#  'Lilyhammer',
#  'The Promise',
#  'Wanderlust',
#  'The World Wars',
#  'The Great Escape',
#  'The New Legends of Monkey',
#  'Relic Hunter',
#  'The Loch',
#  'Way To Go',
#  'Kingdom Hospital',
#  'Angie Tribeca',
#  'Lemon La Vida Loca',
#  'Sex&Drugs&Rock&Roll',
#  'Me, MYSELF & I',
#  'Constantine',
#  "Marley's Ghosts",
#  'Valkyrien',
#  '1600 Penn',
#  'Desperate Housewives',
#  'The Marriage Ref',
#  'Saved By The Bell',
#  'Seven Types of Ambiguity',
#  'Utopia',
#  'Through the Wormhole',
#  'Roommates',
#  'Anzac Girls',
#  'Against the Wall',
#  'I Just Want My Pants Back',
#  'The Cosby Show',
#  'Nighty Night',
#  'Blood and Guts: A History of Surgery',
#  ...]

# %%
show_df = pd.DataFrame(show_list, columns=["show_names"])

# %%
show_df.to_csv("../data/show_list.csv", index=False)

# %%
df = pd.read_csv("../data/show_list.csv")

# %% [markdown]
# #### Adding in the missing year data using IMDb

# %%
shows[shows["show_year"] == 0].groupby("show_names").count()
# Out:
#                                     text  episode_name  season_number  \
# show_names
# 'Til Death                            71            71             71
# 1,000 Places To See Before You Die     2             2              2
# 10 Things I Hate About You            20            20             20
# 100 Questions                          5             5              5
# 1000 Ways to Die                      32            32             32
# ...                                  ...           ...            ...
# Xena: Warrior Princess               134           134            134
# Young Justice                         71            71             71
# Zero Hour                             13            13             13
# five by five                           5             5              5
# iCarly                                95            95             95
#
#                                     episode_number  show_year
# show_names
# 'Til Death                                      71         71
# 1,000 Places To See Before You Die               2          2
# 10 Things I Hate About You                      20         20
# 100 Questions                                    5          5
# 1000 Ways to Die                                32         32
# ...                                            ...        ...
# Xena: Warrior Princess                         134        134
# Young Justice                                   71         71
# Zero Hour                                       13         13
# five by five                                     5          5
# iCarly                                          95         95
#
# [764 rows x 5 columns]

# %%
shows[shows["show_year"] > 0]["show_year"].sort_values()
# Out:
# 30523    1943
# 30525    1943
# 30524    1943
# 30522    1943
# 30521    1943
#          ...
# 80242    2019
# 80241    2019
# 9614     2019
# 57781    2019
# 1919     2019
# Name: show_year, Length: 71268, dtype: int64

# %%
plt.hist(shows[shows["show_year"]!= 0]["show_year"], bins=59)
plt.xlim(1943, 2019);

# %% [markdown]
# ## Creating Dataset containing episode text grouped by show
# ___

# %%
#https://stackoverflow.com/questions/46826773/how-can-i-merge-rows-by-same-value-in-a-column-in-pandas-with-aggregation-func
agg = {"text": "sum", "show_names": "first"}
shows_grouped = shows.groupby(shows["show_names"]).aggregate(agg)
shows_grouped.head()
# Out:
#                                                                                  text  \
# show_names
# 'Allo 'Allo!                        Can it be the breeze that fills the trees  Wit...
# 'Til Death                          I'd like to marry a girl that's skinny. I thin...
# 07 Ghost                            It's that dream again. Just who is that guy? W...
# 1,000 Places To See Before You Die  1 You all might have top-class credentials fro...
# 10 O'Clock Live                     1  Welcome to 10 O'Clock Live. It's Wednesday ...
#
#                                                             show_names
# show_names
# 'Allo 'Allo!                                              'Allo 'Allo!
# 'Til Death                                                  'Til Death
# 07 Ghost                                                      07 Ghost
# 1,000 Places To See Before You Die  1,000 Places To See Before You Die
# 10 O'Clock Live                                        10 O'Clock Live

# %%
shows_grouped = shows_grouped.reset_index(drop=True)

# %%
shows_grouped.tail(10)
# Out:
#                                                    text    show_names
# 4657  1 Thanks.  Oh, there wasn't any sugar.  Legs o...      Zomboat!
# 4658  Hey, Murdoch.  What's the matter, boy? Huh?  W...           Zoo
# 4659  Ole, guapa. Bueno. Ole. Ole. Viva Espana. Ole....         Zorro
# 4660  I wanna be the big man.  - I wanna be the big ...  five by five
# 4661  Carly, get in here. Right now. Have a seat. So...        iCarly
# 4662  1 Liv: This was my life before I died.  17-yea...       iZombie
# 4663  G'd morning Bree!  Hey buddy! Ready for your i...          jPod
# 4664  it's because we all came from the sea. And it ...  seaQuest DSV
# 4665  Hey, where are we going today?  I can see the ...      xxxHOLiC
# 4666  1  [ELECTRICITY GLITCHES.]  [SAMU BREATHING HE...         Élite

# %%
shows_grouped.to_csv("../data/show_text_combined.csv", index=False)
